# %% [markdown]
# **Numerical Feature data dictonary**
# Car_ID = Unique id of each observation (Interger)
# wheelbase = Weelbase of car (Numeric)
# carlength = Length of car (Numeric)
# carwidth = Width of car (Numeric)
# carheight = height of car (Numeric)
# curbweight = The weight of a car without occupants or baggage. (Numeric)
# enginesize = Size of car (Numeric)
# boreratio = Boreratio of car (Numeric)
# stroke = Stroke or volume inside the engine (Numeric)
# compressionratio = compression ratio of car (Numeric)
# horsepower = Horsepower (Numeric)
# peakrpm = car peak rpm (Numeric)
# citympg = Mileage in city (Numeric)
# highwaympg = Mileage on highway (Numeric)
# price(Dependent variable) = Price of car (Numeric)
#
# **Categorical Feature data dictonary**
# Symboling = Its assigned insurance risk rating, A value of +3 indicates that the auto is risky, -3 that it is probably pretty safe.(Categorical)
# carCompany = Name of car company (Categorical)
# fueltype = Car fuel type i.e gas or diesel (Categorical)
# aspiration = Aspiration used in a car (Categorical)
# doornumber = Number of doors in a car (Categorical)
# carbody = body of car (Categorical)
# drivewheel = type of drive wheel (Categorical)
# enginelocation = Location of car engine (Categorical)
# enginetype = Type of engine. (Categorical)
# cylindernumber = cylinder placed in the car (Categorical)
# fuelsystem = Fuel system of car (Categorical)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [6,4]
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('CarPrice_Assignment.csv')
df.head(10)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
# 5       6          2                  audi fox      gas        std        two
# 6       7          1                audi 100ls      gas        std       four
# 7       8          1                 audi 5000      gas        std       four
# 8       9          1                 audi 4000      gas      turbo       four
# 9      10          0       audi 5000s (diesel)      gas      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# ...

# %%
df.drop('car_ID',axis = 1, inplace = True)

# %% [markdown]
# # Shape and Dimension of the Data

# %%
print(f'No.of Rows are {df.shape[0]} and No.of.columns{df.shape[1]}')
print('Dimension of the Dataset{}'.format(df.ndim))
# Out:
# No.of Rows are 205 and No.of.columns25
# Dimension of the Dataset2

# %% [markdown]
# # 5 point summary

# %%
df.describe()
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   CarName           205 non-null    object
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    object
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    object
#  15  enginesize        205 non-null    int64
# ...

# %%
# Splitting the features according to their data types

num_var = df.select_dtypes(include = 'number')
cat_var = df.select_dtypes(include = 'O')

print(f'Number of Numerical Features = {num_var.shape [1]}')
print(f'Number of Categorical Features = {cat_var.shape[1]}')
# Out:
# Number of Numerical Features = 15
# Number of Categorical Features = 10

# %% [markdown]
# # Null Values

# %%
null_values = pd.DataFrame({'null_value_counts': df.isnull().sum(),
                           'nullvalue_percentage': ((df.isnull().sum()/len(df)*100))})
null_values
# Out:
#                   null_value_counts  nullvalue_percentage
# symboling                         0                   0.0
# CarName                           0                   0.0
# fueltype                          0                   0.0
# aspiration                        0                   0.0
# doornumber                        0                   0.0
# carbody                           0                   0.0
# drivewheel                        0                   0.0
# enginelocation                    0                   0.0
# wheelbase                         0                   0.0
# carlength                         0                   0.0
# carwidth                          0                   0.0
# carheight                         0                   0.0
# curbweight                        0                   0.0
# enginetype                        0                   0.0
# cylindernumber                    0                   0.0
# ...

# %% [markdown]
# # Data Vizualization

# %% [markdown]
# # Univariant Analysis for Numerical variable

# %%
for i in num_var:
    print(f'The Skew for {i} is {df[i].skew()}')
    sns.distplot(df[i])
    plt.axvline(df[i].mean(), color = 'r', linestyle = '-.')
    plt.show()
# Out:
# The Skew for symboling is 0.21107227205788776
# The Skew for wheelbase is 1.0502137758714858
# The Skew for carlength is 0.1559537713215604
# The Skew for carwidth is 0.904003498786254
# The Skew for carheight is 0.06312273247192804
# The Skew for curbweight is 0.681398189052588
# The Skew for enginesize is 1.9476550452788108
# The Skew for boreratio is 0.02015641810424137
# The Skew for stroke is -0.6897045784233837
# The Skew for compressionratio is 2.6108624576151533
# The Skew for horsepower is 1.4053101543373119
# The Skew for peakrpm is 0.07515872237118956
# The Skew for citympg is 0.6637040288148164
# The Skew for highwaympg is 0.5399971878746754
# The Skew for price is 1.7776781560914454

# %%
outlier_count={}
for i in num_var:
    outlier= df[(df[i]<df[i].quantile(0.25)-1.5*(df[i].quantile(0.75)-df[i].quantile(0.25))) |
               (df[i]<df[i].quantile(0.75)-1.5*(df[i].quantile(0.75)-df[i].quantile(0.25)))]
    outlier_count[i]=len(outlier)



for i in num_var:
    print(f'outlier of the {i} is : {outlier_count[i]}')
    sns.boxplot(df[i])
    plt.show()
# Out:
# outlier of the symboling is : 3
# outlier of the wheelbase is : 8
# outlier of the carlength is : 27
# outlier of the carwidth is : 3
# outlier of the carheight is : 18
# outlier of the curbweight is : 2
# outlier of the enginesize is : 4
# outlier of the boreratio is : 10
# outlier of the stroke is : 24
# outlier of the compressionratio is : 29
# outlier of the horsepower is : 0
# outlier of the peakrpm is : 20
# outlier of the citympg is : 1
# outlier of the highwaympg is : 9
# outlier of the price is : 0

# %%
for i in num_var:
    sns.scatterplot(y=df[i],x=df['price'])
    plt.show()
    
# price is might affect little by the curb weight and Horse Power

# %% [markdown]
# # Categorical Features

# %%
cat_var.columns
# Out:
# Index(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber',
#        'fuelsystem'],
#       dtype='object')

# %%
x=[]
for i in cat_var:
    x=df[i].value_counts()
    print(x)
# Out:
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: CarName, Length: 147, dtype: int64
# gas       185
# diesel     20
# Name: fueltype, dtype: int64
# std      168
# turbo     37
# Name: aspiration, dtype: int64
# four    115
# two      90
# Name: doornumber, dtype: int64
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64
# front    202
# rear       3
# Name: enginelocation, dtype: int64
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: enginetype, dtype: int64
# four      159
# six        24
# five       11
# ...

# %%
for i in cat_var:
    y = df[i].unique()
    print(y)
# Out:
# ['alfa-romero giulia' 'alfa-romero stelvio' 'alfa-romero Quadrifoglio'
#  'audi 100 ls' 'audi 100ls' 'audi fox' 'audi 5000' 'audi 4000'
#  'audi 5000s (diesel)' 'bmw 320i' 'bmw x1' 'bmw x3' 'bmw z4' 'bmw x4'
#  'bmw x5' 'chevrolet impala' 'chevrolet monte carlo' 'chevrolet vega 2300'
#  'dodge rampage' 'dodge challenger se' 'dodge d200' 'dodge monaco (sw)'
#  'dodge colt hardtop' 'dodge colt (sw)' 'dodge coronet custom'
#  'dodge dart custom' 'dodge coronet custom (sw)' 'honda civic'
#  'honda civic cvcc' 'honda accord cvcc' 'honda accord lx'
#  'honda civic 1500 gl' 'honda accord' 'honda civic 1300' 'honda prelude'
#  'honda civic (auto)' 'isuzu MU-X' 'isuzu D-Max ' 'isuzu D-Max V-Cross'
#  'jaguar xj' 'jaguar xf' 'jaguar xk' 'maxda rx3' 'maxda glc deluxe'
#  'mazda rx2 coupe' 'mazda rx-4' 'mazda glc deluxe' 'mazda 626' 'mazda glc'
#  'mazda rx-7 gs' 'mazda glc 4' 'mazda glc custom l' 'mazda glc custom'
#  'buick electra 225 custom' 'buick century luxus (sw)' 'buick century'
# ...

# %%
for i in cat_var:
    sns.barplot(x=df[i],y=df['price'])
    plt.show()

# %%
plt.figure(figsize=(8,7))
for i in cat_var:
    sns.swarmplot(data=df,x=df[i],y=df['price'])
    plt.show()

# %%
for i in cat_var:
    sns.lineplot(x=df[i],y=df['price'])
    plt.show()

# %%
cat_var.columns
# Out:
# Index(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber',
#        'fuelsystem'],
#       dtype='object')

# %%
for i in cat_var:
    df[i].value_counts().plot(kind='pie',autopct='%.2f')
    plt.show()

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True,mask=np.triu(df.corr(),+1))
plt.show()

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.cov(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# outlier Treatment
# since there are not much deal of outliers, we can transform the data and scale it to interpretable data

# %% [markdown]
# # Train Test Splitting

# %%
num_var.drop('price', axis = 1, inplace = True)

# %%
from sklearn.preprocessing import PowerTransformer

# %%
transform = PowerTransformer(standardize = False)

# %%
for i in num_var:
    df[i] = transform.fit_transform(df[[i]])

# %%
pt = PowerTransformer(method='box-cox')

# %%
df['price'] = pt.fit_transform(df[['price']])

# %%
df.head(10)
# Out:
#    symboling                   CarName fueltype aspiration doornumber  \
# 0   2.558957        alfa-romero giulia      gas        std        two
# 1   2.558957       alfa-romero stelvio      gas        std        two
# 2   0.929685  alfa-romero Quadrifoglio      gas        std        two
# 3   1.770739               audi 100 ls      gas        std       four
# 4   1.770739                audi 100ls      gas        std       four
# 5   1.770739                  audi fox      gas        std        two
# 6   0.929685                audi 100ls      gas        std       four
# 7   0.929685                 audi 5000      gas        std       four
# 8   0.929685                 audi 4000      gas      turbo       four
# 9   0.000000       audi 5000s (diesel)      gas      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front   0.195036   9.597207  ...
# ...

# %% [markdown]
# # Encoding

# %%
cat_var.head(5)
# Out:
#                     CarName fueltype aspiration doornumber      carbody  \
# 0        alfa-romero giulia      gas        std        two  convertible
# 1       alfa-romero stelvio      gas        std        two  convertible
# 2  alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3               audi 100 ls      gas        std       four        sedan
# 4                audi 100ls      gas        std       four        sedan
#
#   drivewheel enginelocation enginetype cylindernumber fuelsystem
# 0        rwd          front       dohc           four       mpfi
# 1        rwd          front       dohc           four       mpfi
# 2        rwd          front       ohcv            six       mpfi
# 3        fwd          front        ohc           four       mpfi
# 4        4wd          front        ohc           five       mpfi

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df['CarName'].value_counts()
# Out:
# toyota corona                      6
# toyota corolla                     6
# peugeot 504                        6
# subaru dl                          4
# mitsubishi mirage g4               3
# mazda 626                          3
# toyota mark ii                     3
# mitsubishi outlander               3
# mitsubishi g4                      3
# honda civic                        3
# volvo 264gl                        2
# bmw 320i                           2
# isuzu D-Max                        2
# audi 100ls                         2
# volvo 244dl                        2
# porsche cayenne                    2
# toyota corolla liftback            2
# honda accord                       2
# bmw x3                             2
# volvo 144ea                        2
# volvo 145e (sw)                    2
# honda civic cvcc                   2
# saab 99le                          2
# toyota starlet                     2
# saab 99gle                         2
# ...

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
df['fueltype'].value_counts()
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64

# %%
df['fueltype'] = label.fit_transform(df['fueltype'])

# %%
df['fueltype'].value_counts()
# Out:
# 1    185
# 0     20
# Name: fueltype, dtype: int64

# %%
df['enginelocation'].value_counts()
# Out:
# front    202
# rear       3
# Name: enginelocation, dtype: int64

# %%
df['enginelocation'] = label.fit_transform(df['enginelocation'])

# %%
df['fuelsystem'].value_counts()
# Out:
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: fuelsystem, dtype: int64

# %% [markdown]
# # Label encoding using Replace function

# %%
df['carbody'].value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64

# %%
df['carbody']= df['carbody'].replace({'sedan':0, 'hatchback': 1, 'wagon':2,'hardtop':3, 'convertible':4 })

# %%
#  label encoding using mapping function

# %%
df['drivewheel'].value_counts()
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64

# %%
wheel = {'fwd':0,'rwd':1, '4wd':2}

# %%
df['drivewheel'] = df['drivewheel'].map(wheel)

# %% [markdown]
# # Frequency encoding

# %%
frequency = df['aspiration'].value_counts(normalize= True)
frequency
# Out:
# std      0.819512
# turbo    0.180488
# Name: aspiration, dtype: float64

# %%
df['aspiration'] = df['aspiration'].replace(frequency)

# %%
engine = df['enginetype'].value_counts(normalize=True)
engine
# Out:
# ohc      0.721951
# ohcf     0.073171
# ohcv     0.063415
# dohc     0.058537
# l        0.058537
# rotor    0.019512
# dohcv    0.004878
# Name: enginetype, dtype: float64

# %%
df['enginetype'] = df['enginetype'].replace(engine)

# %%
door_frequency = df['doornumber'].value_counts()
door_frequency
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
df['doornumber']= df['doornumber'].replace(door_frequency)

# %%
fuel = df['fuelsystem'].value_counts(normalize= True)

# %%
df['fuelsystem']= df['fuelsystem'].map(fuel)

# %%
df.groupby('CarName')['price'].mean()
# Out:
# CarName
# Nissan versa                      -1.822864
# alfa-romero Quadrifoglio           0.826801
# alfa-romero giulia                 0.468026
# alfa-romero stelvio                0.826801
# audi 100 ls                        0.530367
# audi 100ls                         0.930796
# audi 4000                          1.378871
# audi 5000                          1.046370
# audi 5000s (diesel)                0.956091
# audi fox                           0.691582
# bmw 320i                           0.844358
# bmw x1                             1.199425
# bmw x3                             1.546334
# bmw x4                             1.689847
# bmw x5                             1.994745
# bmw z4                             1.416357
# buick century                      1.587712
# buick century luxus (sw)           1.590762
# buick century special              1.986605
# buick electra 225 custom           1.467095
# buick opel isuzu deluxe            1.805470
# ...

# %%
df['CarName'].value_counts()
# Out:
# toyota corona                      6
# toyota corolla                     6
# peugeot 504                        6
# subaru dl                          4
# mitsubishi mirage g4               3
# mazda 626                          3
# toyota mark ii                     3
# mitsubishi outlander               3
# mitsubishi g4                      3
# honda civic                        3
# volvo 264gl                        2
# bmw 320i                           2
# isuzu D-Max                        2
# audi 100ls                         2
# volvo 244dl                        2
# porsche cayenne                    2
# toyota corolla liftback            2
# honda accord                       2
# bmw x3                             2
# volvo 144ea                        2
# volvo 145e (sw)                    2
# honda civic cvcc                   2
# saab 99le                          2
# toyota starlet                     2
# saab 99gle                         2
# ...

# %%
# Dummy encoding

# %%
df = pd.get_dummies(data=df, columns = ['cylindernumber'],drop_first=True)

# %%
df.head(10)
# Out:
#    symboling                   CarName  fueltype  aspiration  doornumber  \
# 0   2.558957        alfa-romero giulia         1    0.819512          90
# 1   2.558957       alfa-romero stelvio         1    0.819512          90
# 2   0.929685  alfa-romero Quadrifoglio         1    0.819512          90
# 3   1.770739               audi 100 ls         1    0.819512         115
# 4   1.770739                audi 100ls         1    0.819512         115
# 5   1.770739                  audi fox         1    0.819512          90
# 6   0.929685                audi 100ls         1    0.819512         115
# 7   0.929685                 audi 5000         1    0.819512         115
# 8   0.929685                 audi 4000         1    0.180488         115
# 9   0.000000       audi 5000s (diesel)         1    0.180488          90
#
#    carbody  drivewheel  enginelocation  wheelbase  carlength  carwidth  \
# 0        4           1               0   0.195036   9.597207  0.134362
# ...

# %% [markdown]
# # Target encoding

# %%
df['CarName'].value_counts('')
# Out:
# toyota corona                      6
# toyota corolla                     6
# peugeot 504                        6
# subaru dl                          4
# mitsubishi mirage g4               3
# mazda 626                          3
# toyota mark ii                     3
# mitsubishi outlander               3
# mitsubishi g4                      3
# honda civic                        3
# volvo 264gl                        2
# bmw 320i                           2
# isuzu D-Max                        2
# audi 100ls                         2
# volvo 244dl                        2
# porsche cayenne                    2
# toyota corolla liftback            2
# honda accord                       2
# bmw x3                             2
# volvo 144ea                        2
# volvo 145e (sw)                    2
# honda civic cvcc                   2
# saab 99le                          2
# toyota starlet                     2
# saab 99gle                         2
# ...

# %%
car_mean = df.groupby('CarName')['price'].mean()

# %%
df['CarName'] = df['CarName'].map(car_mean)

# %%
df.head(10)
# Out:
#    symboling   CarName  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0   2.558957  0.468026         1    0.819512          90        4           1
# 1   2.558957  0.826801         1    0.819512          90        4           1
# 2   0.929685  0.826801         1    0.819512          90        1           1
# 3   1.770739  0.530367         1    0.819512         115        0           0
# 4   1.770739  0.930796         1    0.819512         115        0           2
# 5   1.770739  0.691582         1    0.819512          90        0           0
# 6   0.929685  0.930796         1    0.819512         115        0           0
# 7   0.929685  1.046370         1    0.819512         115        2           0
# 8   0.929685  1.378871         1    0.180488         115        0           0
# 9   0.000000  0.956091         1    0.180488          90        1           2
#
#    enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'enginesize',
#        'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'citympg', 'highwaympg', 'price', 'cylindernumber_five',
#        'cylindernumber_four', 'cylindernumber_six', 'cylindernumber_three',
#        'cylindernumber_twelve', 'cylindernumber_two'],
#       dtype='object')

# %%
re =['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
       'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
       'carwidth', 'carheight', 'curbweight', 'enginetype', 'enginesize',
       'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
       'peakrpm', 'citympg', 'highwaympg', 'cylindernumber_five',
       'cylindernumber_four', 'cylindernumber_six', 'cylindernumber_three',
       'cylindernumber_twelve', 'cylindernumber_two','price']

# %%
df = df[re]

# %%
df.head(10)
# Out:
#    symboling   CarName  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0   2.558957  0.468026         1    0.819512          90        4           1
# 1   2.558957  0.826801         1    0.819512          90        4           1
# 2   0.929685  0.826801         1    0.819512          90        1           1
# 3   1.770739  0.530367         1    0.819512         115        0           0
# 4   1.770739  0.930796         1    0.819512         115        0           2
# 5   1.770739  0.691582         1    0.819512          90        0           0
# 6   0.929685  0.930796         1    0.819512         115        0           0
# 7   0.929685  1.046370         1    0.819512         115        2           0
# 8   0.929685  1.378871         1    0.180488         115        0           0
# 9   0.000000  0.956091         1    0.180488          90        1           2
#
#    enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# ...

# %% [markdown]
# # Train test Split

# %%
x = df.drop('price',axis = 1)
y = df['price']

# %%
from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.20, random_state=42)

# %%
print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (164, 29)
# (41, 29)
# (164,)
# (41,)

# %%
xtrain.head()
# Out:
#      symboling   CarName  fueltype  aspiration  doornumber  carbody  \
# 66    0.000000  0.743679         0    0.819512         115        0
# 111   0.000000  0.686193         1    0.819512         115        0
# 153   0.000000 -1.109166         1    0.819512         115        2
# 96    0.929685 -1.010061         1    0.819512         115        0
# 38    0.000000 -0.382617         1    0.819512          90        1
#
#      drivewheel  enginelocation  wheelbase  carlength  carwidth  carheight  \
# 66            1               0   0.195036   9.710149  0.134362   8.880431
# 111           1               0   0.195036   9.915117  0.134362   9.050288
# 153           0               0   0.195036   9.613798  0.134362   9.222930
# 96            0               0   0.195036   9.532026  0.134362   8.887910
# 38            0               0   0.195036   9.573120  0.134362   8.797583
#
#      curbweight  enginetype  enginesize  fuelsystem  boreratio     stroke  \
# ...

# %%
# Scaling
# done scaling after train test due to information leakage

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
for i in num_var:
    xtrain[i] = scaler.fit_transform(xtrain[[i]])
    xtest[i] = scaler.transform(xtest[[i]])

# %%
xtest.head(10)
# Out:
#      symboling   CarName  fueltype  aspiration  doornumber  carbody  \
# 15   -0.686505  1.689847         1    0.819512         115        0
# 9    -0.686505  0.956091         1    0.180488          90        1
# 100  -0.686505 -0.265853         1    0.819512         115        0
# 132   1.589451  0.616210         1    0.819512          90        1
# 68   -1.644541  1.590762         0    0.180488         115        2
# 95    0.140364 -0.775438         1    0.819512          90        1
# 159  -0.686505 -0.308096         0    0.819512         115        1
# 162  -0.686505 -0.446323         1    0.819512         115        0
# 147  -0.686505 -0.113795         1    0.819512         115        2
# 182   0.888404 -0.783708         0    0.819512          90        0
#
#      drivewheel  enginelocation  wheelbase  carlength      carwidth  \
# 15            1               0   0.940993   1.226100  4.440892e-16
# 9             2               0   0.319445   0.362760  7.771561e-16
# ...

# %%
xtrain.head(10)
# Out:
#      symboling   CarName  fueltype  aspiration  doornumber  carbody  \
# 66   -0.686505  0.743679         0    0.819512         115        0
# 111  -0.686505  0.686193         1    0.819512         115        0
# 153  -0.686505 -1.109166         1    0.819512         115        2
# 96    0.140364 -1.010061         1    0.819512         115        0
# 38   -0.686505 -0.382617         1    0.819512          90        1
# 24    0.140364 -1.422595         1    0.819512         115        1
# 139   0.888404 -0.604512         1    0.819512          90        1
# 112  -0.686505  0.924150         0    0.180488         115        0
# 29    1.589451  0.390800         1    0.180488          90        1
# 19    0.140364 -1.390165         1    0.819512          90        1
#
#      drivewheel  enginelocation  wheelbase  carlength      carwidth  \
# 66            1               0   1.126055   0.099199  1.665335e-16
# 111           1               0   1.475745   1.045499  9.159340e-16
# ...

# %% [markdown]
# # Base Model

# %%
import statsmodels.api as sma
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error

# %%
stat_model = sma.OLS(ytrain,sma.add_constant(xtrain)).fit()
stat_model.summary()

# since there is a singular matrix error we go for Generalized Linear Model
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.949
# Method:                 Least Squares   F-statistic:                     112.3
# Date:                Thu, 05 Oct 2023   Prob (F-statistic):           9.19e-80
# Time:                        09:12:09   Log-Likelihood:                 25.031
# No. Observations:                 164   AIC:                             5.937
# Df Residuals:                     136   BIC:                             92.73
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Linear Regression Model

# %%
linear=LinearRegression()

linear_model=linear.fit(xtrain,ytrain)

# %%
linear_predict_train = linear_model.predict(xtrain)
linear_predict_test = linear_model.predict(xtest)


print(linear_predict_train)
print(linear_predict_test)
# Out:
# [ 0.58930986  0.68670935 -1.20314725 -1.11472913 -0.5290317  -1.31906761
#  -1.02457515  0.92550728  0.44720898 -1.47198044  0.62787043 -1.11089559
#  -0.30287491 -1.0544755   0.55602777 -0.1306179   0.26498602  1.86619245
#  -1.67713385 -0.41416047  1.03858855 -0.31662027  0.96359243  0.00571472
#  -1.32499854  0.88096763 -0.97723891  1.19897121 -0.1262514  -0.74938847
#   0.77748973 -0.9359777  -1.61524882  0.74221211 -0.14741211 -0.34936326
#   0.47641104 -0.81766838 -0.76288045 -0.97234573  0.77481822  0.81468827
#   0.98509015  0.88148886 -1.43104971 -0.13457805 -0.7944771   1.78858112
#  -0.65016576 -1.63300456 -1.02927375  1.00138725 -0.25150069 -1.47133051
#   0.82655647  0.25034641 -1.30716677  0.63360146  1.15245018 -0.47091976
#   0.92067064 -0.48560932  1.78592703  0.96779427 -1.2794663   1.02602621
#  -1.53183092  0.40822863 -0.2744909   0.59558038 -0.62799101  0.56521194
#  -0.49458351 -1.56150276 -1.84809828  0.29103872  0.35771329 -0.74223502
# ...

# %%
r2_train = r2_score(ytrain, linear_predict_train)
r2_test = r2_score(ytest, linear_predict_test)

print(r2_train)
print(r2_test)

# Model performed well in training yet not well in test
# Out:
# 0.9570856725587057
# 0.9183762609551155

# %%
print("MSE Train :",mean_squared_error(ytrain,linear_predict_train))
print("MSE Train :",mean_squared_error(ytest,linear_predict_test))
# Out:
# MSE Train : 0.04314720716294063
# MSE Train : 0.0798420222971378

# %%
plt.figure(figsize=(8, 6))
plt.scatter(ytest, linear_predict_test, label='Actual vs predict')
plt.plot([min(ytest), max(ytest)], [min(ytest), max(ytest)])
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(ytest,linear_predict_test, label='Actual vs predict')
plt.plot([min(ytest),max(ytest)], [min(linear_predict_test),max(linear_predict_test)])
plt.show()

# %% [markdown]
# # Decision Tree model

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree = DecisionTreeRegressor()

# %%
tree_model = tree.fit(xtrain,ytrain)

# %% [markdown]
# # Model Evaluation

# %%
tree_pred_train = tree_model.predict(xtrain)
tree_pred_test = tree_model.predict(xtest)

# %%
r2_tree_train = r2_score(ytrain,tree_pred_train)
print(f'R2 score of the tree model train is {r2_tree_train}\n')
r2_tree_test = r2_score(ytest , tree_pred_test)
print(f'R2 score of the tree model test is {r2_tree_test}\n')
# Out:
# R2 score of the tree model train is 1.0
#
# R2 score of the tree model test is 0.8682589809973201

# %% [markdown]
# # Model Performance Evaluation

# %%
tree_rmse_train = np.sqrt(mean_squared_error(ytrain,tree_pred_train )) 
print(f'RMSE for tree train model is {tree_rmse_train}\n')
tree_rmse_test = np.sqrt(mean_squared_error(ytest,tree_pred_test )) 
print(f'RMSE for tree train model is {tree_rmse_test}\n')
# Out:
# RMSE for tree train model is 0.0
#
# RMSE for tree train model is 0.3589781630293929

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
Random_forest = RandomForestRegressor()

# %%
forest_model = Random_forest.fit(xtrain, ytrain)

# %%
forest_pred_train = forest_model.predict(xtrain)
forest_pred_test = forest_model.predict(xtest)

# %% [markdown]
# # Random Forest Model Evalution

# %%
randomfr_r2_train = r2_score(ytrain , forest_pred_train)
randomfr_r2_test = r2_score(ytest , forest_pred_test)
print(f'R2 score of the Random Forest train {randomfr_r2_train}\n')
print(f'R2 score of the Random Forest test {randomfr_r2_test}')
# Out:
# R2 score of the Random Forest train 0.9914148177251728
#
# R2 score of the Random Forest test 0.937853115714215

# %% [markdown]
# # Random Forest Perfomance Metric

# %%
Randomfr_rmse_train = np.sqrt(mean_squared_error(ytrain , forest_pred_train))
Randomfr_rmse_test = np.sqrt(mean_squared_error(ytest , forest_pred_test))

print(f'Rmse score for the Random forest train model {Randomfr_rmse_train}\n')
print(f'Rmse score for the Random forest test model {Randomfr_rmse_test}')
# Out:
# Rmse score for the Random forest train model 0.09290732366974816
#
# Rmse score for the Random forest test model 0.24655692320898467

# %% [markdown]
# # Regularization

# %% [markdown]
# # Ridge Model

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge(alpha=0.25)

# %%
ridge_model.fit(xtrain,ytrain)
# Out:
# Ridge(alpha=0.25)

# %%
ridge_pred_train = ridge_model.predict(xtrain)
ridge_pred_test = ridge_model.predict(xtest)

# %%
print(f'R2 score for the ridge model train {r2_score(ytrain , ridge_pred_train)}\n')
print(f'R2 score for the ridge model test {r2_score(ytest , ridge_pred_test)}')
# Out:
# R2 score for the ridge model train 0.9568549596550785
#
# R2 score for the ridge model test 0.9274229929498506

# %%
rmse_train = np.sqrt(mean_squared_error(ytrain , ridge_pred_train))
rmse_test = np.sqrt(mean_squared_error(ytest , ridge_pred_test))
print(f'Rmse score for the Ridge train model {rmse_train}\n')
print(f'Rmse score for the Ridge test model {rmse_test}\n')
# Out:
# Rmse score for the Ridge train model 0.20827667189986865
#
# Rmse score for the Ridge test model 0.26644467739377903

# %%
pd.DataFrame(ridge_model.coef_,xtrain.columns).plot(kind='bar')
plt.show()

# %% [markdown]
# # Lasso Model

# %%
from sklearn.linear_model import Lasso

# %%
Lasso_model = Lasso(alpha=0.10)

# %%
Lasso_model.fit(xtrain, ytrain)
# Out:
# Lasso(alpha=0.1)

# %%
lasso_pred_train = Lasso_model.predict(xtrain)
lasso_pred_test = Lasso_model.predict(xtest)

# %% [markdown]
# # Model Evaluation

# %%
r2_train = r2_score(ytrain , lasso_pred_train)
r2_test = r2_score(ytest , lasso_pred_test)
print(f'R2 score for the Lasso model train {r2_train}\n')
print(f'R2 score for the Lasso model test {r2_test}')
# Out:
# R2 score for the Lasso model train 0.9343620771619623
#
# R2 score for the Lasso model test 0.954495467627015

# %% [markdown]
# # Model Performace Evaluation

# %%
lasso_rmse_train = np.sqrt(mean_squared_error(ytrain , lasso_pred_train))
lasso_rmse_test = np.sqrt(mean_squared_error(ytest , lasso_pred_test))

print(f'Rmse score for the Lasso train model {lasso_rmse_train}\n')
print(f'Rmse score for the Lasso test model {lasso_rmse_train}')
# Out:
# Rmse score for the Lasso train model 0.25689319738600347
#
# Rmse score for the Lasso test model 0.25689319738600347

# %%
pd.DataFrame(Lasso_model.coef_,xtrain.columns).plot(kind='bar')
plt.show()

# %% [markdown]
# # Hyper parameter Tuning

# %% [markdown]
# # Decision Tree Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
tuned_paramaters = [{'criterion': ['squared_error'], 
                     'max_depth': [17,20,24],
                     'max_features': ["sqrt", "log2"],
                     'min_samples_split': [7,10,15],
                     'min_samples_leaf': [3,5,10],
                     'max_leaf_nodes': [3,5,7]}]

decision_tree_regressor = DecisionTreeRegressor(random_state = 42)

decision_tree_grid = GridSearchCV(estimator = decision_tree_regressor,param_grid = tuned_paramaters,verbose=3)

# %%
decision_tree_grid.fit(xtrain,ytrain)
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# [CV 1/5] END criterion=squared_error, max_depth=17, max_features=sqrt, max_leaf_nodes=3, min_samples_leaf=3, min_samples_split=7;, score=0.733 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=17, max_features=sqrt, max_leaf_nodes=3, min_samples_leaf=3, min_samples_split=7;, score=0.703 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=17, max_features=sqrt, max_leaf_nodes=3, min_samples_leaf=3, min_samples_split=7;, score=0.350 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=17, max_features=sqrt, max_leaf_nodes=3, min_samples_leaf=3, min_samples_split=7;, score=0.763 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=17, max_features=sqrt, max_leaf_nodes=3, min_samples_leaf=3, min_samples_split=7;, score=0.791 total time=   0.0s
# ...

# %% [markdown]
# # Finding the Best Paramters

# %%
print('Best parameters for decision tree Regressor: ', decision_tree_grid.best_params_, '\n')
# Out:
# Best parameters for decision tree Regressor:  {'criterion': 'squared_error', 'max_depth': 17, 'max_features': 'log2', 'max_leaf_nodes': 7, 'min_samples_leaf': 5, 'min_samples_split': 7}

# %% [markdown]
# # Model from the best params

# %%
dt_model = DecisionTreeRegressor(criterion = decision_tree_grid.best_params_.get('criterion'),
                                  max_depth = decision_tree_grid.best_params_.get('max_depth'),
                                  max_features = decision_tree_grid.best_params_.get('max_features'),
                                  max_leaf_nodes = decision_tree_grid.best_params_.get('max_leaf_nodes'),
                                  min_samples_leaf = decision_tree_grid.best_params_.get('min_samples_leaf'),
                                  min_samples_split = decision_tree_grid.best_params_.get('min_samples_split'),
                                  random_state = 10)

dt_model = dt_model.fit(xtrain, ytrain)

# %% [markdown]
# # Model evaluation

# %%
dt_pred_train = dt_model.predict(xtrain)
dt_pred_test = dt_model.predict(xtest)

# %%
r2_train = r2_score(ytrain , dt_pred_train)
r2_test = r2_score(ytest , dt_pred_test)
print(f'GSCV_tree model Train R2 score{r2_train}')
print(f'GSCV_tree model Test R2 score{r2_test}')
# Out:
# GSCV_tree model Train R2 score0.8067218625369251
# GSCV_tree model Test R2 score0.6844931674165055

# %% [markdown]
# # Model Performance Evaluation

# %%
rmse_train = np.sqrt(mean_squared_error(ytrain , dt_pred_train))
rmse_test = np.sqrt(mean_squared_error(ytest , dt_pred_test))

print(f'GSCV_tree model Train RMSE score {rmse_train}')
print(f'GSCV_tree model test RMSE score {rmse_test}')
# Out:
# GSCV_tree model Train RMSE score 0.440825344498926
# GSCV_tree model test RMSE score 0.5555356144305291

# %% [markdown]
# # Random Forest Tuning

# %%
params = {'n_estimators' : [150 , 175 ,200],
         'criterion' : ['squared_error'],
         'max_features' : [None, 'sqrt' , 'log']}
grid_rf = GridSearchCV(estimator= RandomForestRegressor() , param_grid = params ).fit(xtrain , ytrain)

# %%
print(grid_rf.best_params_)
# Out:
# {'criterion': 'squared_error', 'max_features': None, 'n_estimators': 150}

# %%
model_rf_tuned = grid_rf.best_estimator_.fit(xtrain , ytrain)

# %%
rf_pred_train = model_rf_tuned.predict(xtrain)
rf_pred_test = model_rf_tuned.predict(xtest)

# %% [markdown]
# # Tuned Random Forest Model Evaluation

# %%
r2_train = r2_score(ytrain , rf_pred_train)
r2_test = r2_score(ytest , rf_pred_test)
print(f'GSCV_rf model Train RMSE score {r2_train}\n')
print(f'GSCV_rf model Train RMSE score {r2_test}')
# Out:
# GSCV_rf model Train RMSE score 0.9918434045766227
#
# GSCV_rf model Train RMSE score 0.9404891416301207

# %% [markdown]
# # Tuned Random Forest Model Performace score

# %%
rmse_train = np.sqrt(mean_squared_error(ytrain , rf_pred_train))
rmse_test = np.sqrt(mean_squared_error(ytest , rf_pred_test))

print(f'GSCV_rf model Train RMSE score {rmse_train}\n')
print(f'GSCV_rf model Train RMSE score {rmse_test}')
# Out:
# GSCV_rf model Train RMSE score 0.09055858966605385
#
# GSCV_rf model Train RMSE score 0.24127128036864515

# %% [markdown]
# # Model Boosting

# %%
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
adaboost = AdaBoostRegressor()

# %%
ada_model = adaboost.fit(xtrain,ytrain)

# %%
ada_train_pred = ada_model.predict(xtrain)
ada_test_pred = ada_model.predict(xtest)

# %% [markdown]
# # Ada Boost Model Evaluation

# %%
ada_r2score_train = r2_score(ytrain,ada_train_pred)
print(f'AdaBoost model Train R2 score {ada_r2score_train}\n')
ada_r2score_test = r2_score(ytest, ada_test_pred)
print(f'AdaBoost model Test R2 score {ada_r2score_test}')
# Out:
# AdaBoost model Train R2 score 0.9751452769020275
#
# AdaBoost model Test R2 score 0.9486759634835367

# %% [markdown]
# # Ada Boost Model Performance Evaluation

# %%
ada_rmse_train = np.sqrt(mean_squared_error(ytrain,ada_train_pred))
print(f'AdaBoost model Train Rmse score {ada_rmse_train}')
ada_rmse_test = np.sqrt(mean_squared_error(ytest,ada_test_pred))
print(f'AdaBoost model Test RMSE score {ada_rmse_test}')
# Out:
# AdaBoost model Train Rmse score 0.15808099259686717
# AdaBoost model Test RMSE score 0.22406185354055388

# %% [markdown]
# # Gradiant Boosting

# %%
Gradiantboost = GradientBoostingRegressor()

# %%
gradiant_model = Gradiantboost.fit(xtrain,ytrain)

# %%
gradiant_ytrain = gradiant_model.predict(xtrain)
gradiant_ytest = gradiant_model.predict(xtest)

# %% [markdown]
# # Model Evaluation

# %%
r2_gradiant_train = r2_score(ytrain,gradiant_ytrain)
print(f'Gradiant model Train R2 score {r2_gradiant_train}')
r2_gradiant_test = r2_score(ytest,gradiant_ytest)
print(f'Gradiant model Test R2 score {r2_gradiant_test}')
# Out:
# Gradiant model Train R2 score 0.9950668675771752
# Gradiant model Test R2 score 0.9345028205359457

# %% [markdown]
# # Model Performance

# %%
gradiant_rmse_train = np.sqrt(mean_squared_error(ytrain,gradiant_ytrain))
print(f'Gradiant model Train RMSE score {gradiant_rmse_train}')
gradiant_rmse_test = np.sqrt(mean_squared_error(ytest,gradiant_ytest))
print(f'Gradiant model Test RMSE score {gradiant_rmse_test}')
# Out:
# Gradiant model Train RMSE score 0.07042657633956158
# Gradiant model Test RMSE score 0.2531155466011767

# %% [markdown]
# # k-fold cross validation

# %%
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
model = LinearRegression()

# %%
for train_index, test_index in kf.split(xtrain):
    # Split the data into training and testing sets for this fold
    x_train_fold, x_test_fold = xtrain.iloc[train_index], xtrain.iloc[test_index]
    y_train_fold, y_test_fold = ytrain.iloc[train_index], ytrain.iloc[test_index]

# %%
 model.fit(x_train_fold, y_train_fold)
# Out:
# LinearRegression()

# %%
  y_pred = model.predict(x_test_fold)

# %%
mse_scores = []

# %%
mse = mean_squared_error(y_test_fold, y_pred)
mse_scores.append(mse)

# %%
mse_scores
# Out:
# [0.07809890209161804]

# %%
average_mse = np.mean(mse_scores)
print(average_mse)
# Out:
# 0.07809890209161804

# %%
# Inference
